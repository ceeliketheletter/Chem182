# %% [markdown]
# # VIBRATIONAL SPECTROSCOPY AND GLOBAL (GREENHOUSE) WARMING POTENTIALS OF POLYATOMIC MOLECULES

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ### Procedure:
# #### Obtain a gas cell with 20 mm Hg (Torr) SO2, CH4  (60  mm  Hg), Methylene chloride CH2Cl2 (10 mm Hg), Tetrafluoroethane CF3CH2F (4 mm Hg)

# %% [markdown]
# data is wavenumber in 1/cm and absorbance (no units)
# dont worry about absorbance values under zero.
# Just label SO2 peaks as 2, 1, 3 increasing in frequency

# %%
methaline = np.loadtxt('/Users/CEE/Desktop/RCCGLab3/methaline_chloride.csv', delimiter = ',')
meth_wavenumber = np.rot90(methaline)[1]
meth_absorbance = np.rot90(methaline)[0]

methane = np.loadtxt('/Users/CEE/Desktop/RCCGLab3/RCCGMethane_absorbance.csv', delimiter = ',')
methane_wavenumber = np.rot90(methane)[1]
methane_absorbance = np.rot90(methane)[0]

tetra = np.loadtxt('/Users/CEE/Desktop/RCCGLab3/tetra.csv', delimiter = ',')
tetra_wavenumber = np.rot90(tetra)[1]
tetra_absorbance = np.rot90(tetra)[0]

SO2 = np.loadtxt('/Users/CEE/Desktop/RCCGLab3/SO2-20TORR.csv', delimiter = ',')
SO2_wavenumber = np.rot90(SO2)[1]
SO2_absorbance = np.rot90(SO2)[0]

# %%
plt.figure(figsize = (10,5))
plt.plot(meth_wavenumber, meth_absorbance, 'k.')
plt.xlabel('Wavenumber in 1/cm')
plt.ylabel('Absorbance')
plt.title('Methaline chloride')
plt.xlim(200, 3200)
plt.ylim(-0.25, 1.5)
plt.show()

plt.figure(figsize = (10,5))
plt.plot(methane_wavenumber, methane_absorbance, 'k.')
plt.xlabel('Wavenumber in 1/cm')
plt.ylabel('Absorbance')
plt.title('Methane')
plt.xlim(200, 3200)
plt.ylim(-0.25, 1.5)
plt.show()

plt.figure(figsize = (10,5))
plt.plot(tetra_wavenumber, tetra_absorbance, 'k.')
plt.xlabel('Wavenumber in 1/cm')
plt.ylabel('Absorbance')
plt.xlim(200, 3200)
plt.ylim(-0.25, 1.5)
plt.title('Tetrafluoroethane')
plt.show()

plt.figure(figsize = (10,5))
plt.plot(SO2_wavenumber, SO2_absorbance, 'k.')
plt.xlabel('Wavenumber in 1/cm')
plt.ylabel('Absorbance')
plt.xlim(200, 3200)
plt.ylim(-0.25, 1.5)
plt.title('SO2')
plt.show()

# %% [markdown]
# ## Data Analysis and Questions
# ### In your lab notebook write out the following:
# 1.In a few sentences, explain how the FTIR spectrometer works. Draw a block diagram of the Michelson interferometer. Include the interferogram you took of the empty cell; label the axes. How is this different from the UV-Vis spectra you took in Lab 1?

# %% [markdown]
# 2.Sketch and label the normal vibrational modes of SO2. Which are IR active? Why or why not?

# %% [markdown]
# 3.Recalling  that  ν3  >  ν1  >  ν2,  assign  the  fundamental  transitions  in  your  SO2  spectra  and  determine their frequency values.

# %%
V3_frequency =  SO2_wavenumber[np.argmin(SO2_absorbance[860:890])]+860
V3_absorbance = np.min(SO2_absorbance[860:890])

V1_frequency= SO2_wavenumber[np.argmin(SO2_absorbance[650:668])]+650 
V1_absorbance = np.min(SO2_absorbance[650:668])

V2_frequency = (SO2_wavenumber[np.argmin(SO2_absorbance[:60])])
V2_absorbance = (np.min(SO2_absorbance[:60]))

plt.figure(figsize = (15,5))
plt.semilogy(SO2_wavenumber, SO2_absorbance, 'k.')

plt.plot(V2_frequency, V2_absorbance, 'ro', label = 'V2: ' + str(V2_frequency))
plt.plot(V1_frequency, V1_absorbance, 'bo', label = 'V1: ' + str(V1_frequency))
plt.plot(V3_frequency, V3_absorbance, 'go', label = 'V3: ' + str(V3_frequency))

plt.xlabel('Wavenumber in 1/cm')
plt.ylabel('Absorbance')
#plt.xlim(470, 1500)
#plt.xlim(0,1000)
plt.ylim(-0.25, 1.5)
plt.title('SO2 Spectra')
plt.legend()
plt.show()


plt.plot(SO2_wavenumber[560:800], SO2_absorbance[560:800], 'k.')
plt.plot(V1_frequency, V1_absorbance, 'bo', label = 'V1: ' + str(V1_frequency))
plt.xlabel('Wavenumber in 1/cm')
plt.ylabel('Absorbance')
plt.title('SO2 V1 Spectra')
plt.legend()
plt.show()


plt.plot(SO2_wavenumber[:100], SO2_absorbance[:100], 'k.')
plt.plot(V2_frequency, V2_absorbance, 'ro', label = 'V2: ' + str(V2_frequency))
plt.xlabel('Wavenumber in 1/cm [830:950]')
plt.ylabel('Absorbance')
plt.title('SO2 V2 Spectra')
plt.legend()
plt.show()


plt.plot(SO2_wavenumber[830:950], SO2_absorbance[830:950], 'k.')
plt.plot(V3_frequency, V3_absorbance, 'go', label = 'V3: ' + str(V3_frequency))
plt.xlabel('Wavenumber in 1/cm')
plt.ylabel('Absorbance')
plt.title('SO2 V3 Spectra')
plt.legend()
plt.show()
# Out:
# /Users/CEE/anaconda3/lib/python3.6/site-packages/matplotlib/axes/_base.py:3449: UserWarning: Attempted to set non-positive ylimits for log-scale axis; invalid limits will be ignored.
#   'Attempted to set non-positive ylimits for log-scale axis; '

# %% [markdown]
# 3. Using these values, calculate the expected frequencies of the following overtones and combinations bands: 2 ν1, 2 ν2, 2 ν3, ν1+ ν2, ν1+ ν3, ν2+ ν3in order to assign any of these transitions that appear in your  spectrum.  Label  the  peaks  on the spectra with their assignments and frequencies.

# %%
two_V1 = V1_frequency *2
two_V2 = V2_frequency *2
two_V3 = V3_frequency *2
V1_plus_V2 = V1_frequency + V2_frequency
V1_plus_V3 = V1_frequency + V3_frequency
V2_plus_V3 = V2_frequency + V3_frequency

print('V3', V3_frequency)
print('V2', V2_frequency)
print('V1', V1_frequency)
print('two_V1', two_V1)
print('two_V2', two_V2)
print('two_V3', two_V3)
print('V1_plus_V2', V1_plus_V2)
print('V1_plus_V3', V1_plus_V3)
print('V2_plus_V3', V2_plus_V3)


plt.figure(figsize = (15,7))
plt.semilogy(SO2_wavenumber, SO2_absorbance, 'k-')


plt.plot(V3_frequency, V3_absorbance, 'y*', markersize=30, label = 'V3: ' + str(V3_frequency))
plt.text(V3_frequency, V3_absorbance + 0.2 , 'V3', fontsize=30)

plt.plot(two_V3, .02, 'y|', markersize=30, label = '2 * V3: ' + str(two_V3))
plt.text(two_V3-100, 0.06 , '2 * V3', fontsize=15)

plt.plot(V1_frequency, V1_absorbance, 'b*', markersize=30, label = 'V1: ' + str(V1_frequency))
plt.text(V1_frequency, V1_absorbance + 0.1 , 'V1', fontsize=30)

plt.plot(V2_frequency, V2_absorbance, 'r*', markersize=30, label = 'V2: ' + str(V2_frequency))
plt.text(V2_frequency + 100, V2_absorbance, 'V2', fontsize=30)


plt.plot(V1_plus_V3, .06, 'g', marker = '1', markersize=40, label = 'V1 + V3: ' + str(V1_plus_V3))
plt.text(V1_plus_V3-100, 0.1 , 'V1 + V3', fontsize=15)


plt.plot(V2_plus_V3, .04, 'tab:orange', marker = '1', markersize=40, label = 'V2 + V3: ' + str(V2_plus_V3))
plt.text(V2_plus_V3-50, 0.1 , 'V2 + V3', fontsize=15)

plt.plot(two_V1, .02, 'b|', markersize=30, label = '2 * V1: ' + str(two_V1))
plt.text(two_V1-100, 0.06 , '2 * V1', fontsize=15)

plt.plot(V1_plus_V2, .04, 'tab:purple', marker = '1', markersize=40, label = 'V1 + V2: ' + str(V1_plus_V2))
plt.text(V1_plus_V2-100, 0.1 , 'V1 + V2', fontsize=15)

plt.plot(two_V2, .02, 'r|', markersize=30, label = '2 * V2: ' + str(two_V2))
plt.text(two_V2-100, 0.06 , '2 * V2', fontsize=15)



plt.xlabel('Wavenumber in 1/cm')
plt.ylabel('Absorbance')
plt.ylim(0.0001, 1)
plt.xlim(400, 3000)
plt.title('SO2 Spectra')
plt.legend()
plt.show()
# Out:
# V3 1360.0
# V2 519.0
# V1 1150.0
# two_V1 2300.0
# two_V2 1038.0
# two_V3 2720.0
# V1_plus_V2 1669.0
# V1_plus_V3 2510.0
# V2_plus_V3 1879.0

# %%
real_V1_plus_V3 = 2500
lit_V1_plus_V3 = 2499

plt.plot(lit_V1_plus_V3, .00, 'r', marker = '*', markersize=10, label = 'lit: ' + str(lit_V1_plus_V3))
plt.plot(real_V1_plus_V3, .00, 'b', marker = '*', markersize=10, label = 'observed: ' + str(real_V1_plus_V3))
plt.plot(V1_plus_V3, .00, 'g', marker = '*', markersize=10, label = 'estimated: ' + str(V1_plus_V3))
plt.plot(SO2_wavenumber[2000:2150], SO2_absorbance[2000:2150], 'k.')
plt.xlabel('Wavenumber in 1/cm ')
plt.ylabel('Absorbance')
plt.title('SO2 V1 + V3 Spectra')
plt.legend()
plt.show()

real_V2_plus_V3 = 1880
lit_V2_plus_V3 = 1871

plt.plot(lit_V2_plus_V3, .002, 'r', marker = '*', markersize=10, label = 'lit: ' + str(lit_V2_plus_V3))
plt.plot(real_V2_plus_V3, .002, 'b', marker = '*', markersize=10, label = 'observed: ' + str(real_V2_plus_V3))
plt.plot(V2_plus_V3, .002, 'g', marker = '*', markersize=10, label = 'estimated: ' + str(V2_plus_V3))
plt.plot(SO2_wavenumber[1350:1500], SO2_absorbance[1350:1500], 'k.')
plt.xlabel('Wavenumber in 1/cm ')
plt.ylabel('Absorbance')
plt.title('SO2 V2 + V3 Spectra')
plt.xlim(1840, 1920)
plt.legend(loc = 3)
plt.show()

lit_two_v1 = 2305
plt.plot(lit_two_v1, .002, 'r', marker = '*', markersize=10, label = 'lit: ' + str(lit_two_v1))
#plt.plot(real_V2_plus_V3, .002, 'b', marker = '*', markersize=10, label = 'observed: ' + str(real_V2_plus_V3))
plt.plot(two_V1, .002, 'g', marker = '*', markersize=10, label = 'estimated: ' + str(two_V1))
plt.plot(SO2_wavenumber[1800:1900], SO2_absorbance[1800:1900], 'k.')
plt.xlabel('Wavenumber in 1/cm ')
plt.ylabel('Absorbance')
plt.title('SO2 2V1 Spectra')
plt.legend()
plt.show()


#plt.plot(real_V2_plus_V3, .002, 'b', marker = '*', markersize=10, label = 'observed: ' + str(real_V2_plus_V3))
plt.plot(two_V3, .004, 'g', marker = '*', markersize=10, label = 'estimated: ' + str(two_V3))
plt.plot(SO2_wavenumber[2200:2900], SO2_absorbance[2200:2900], 'k.')
plt.xlabel('Wavenumber in 1/cm ')
plt.ylabel('Absorbance')
plt.title('SO2 2V3 Spectra')
plt.legend()
plt.show()

# %% [markdown]
# 4.For SO2, construct a single data table with columns for (1) the identity of the absorption band  (i.e.,  ν1, ν1+ν2,  etc.),  (2)  the  observed  frequency  of  the  band  origin  for  each  absorption, (3) the expected frequency -- calculated in question 3 -- if the transition is an overtone  and  combination  band,  and  the  literature  value  for  the  transition.  [Literature  values  can  be  found  in  Gerhard  Herzberg,  Molecular  Spectra  and  Molecular  Structure,vol  2:  Infrared  and  Raman  Spectra  of  Polyatomic  Molecules,  1945,  in  the  chemistrylibrary (QC451 .H455 v.2); they have one non-circulating copy (ask at the front desk) and several other available copies on the shelves.]

# %% [markdown]
# 5.Calculating  GWPs:  You  will  then  have  data  with  wavenumber in the first column and absorbance in the second column. Starting with the data  at  500  cm-1,  paste  these  into  the  first  two  columns  of  the  Excel  template  you  obtained  from  bcourses.  Enter  the  appropriate  values  for  cell  pressure,  atmospheric  lifetime, molecular weight, and path length for each gas. Carry out a greenhouse warming potential  calculation  for  your  greenhouse  gases  using  the  10  cm-1  intervals  that  you  integrated  using  the  template.  If  your  baseline  is  offset  or  noisy  it  may  be  helpful  to  delete the data that do not correspond to peaks in your spectra as they will only contribute noise.  If  you  do  have  a  low-noise  and  steady  background,  you  do  not  need  to  delete  all  the  data  that  do  not  correspond  to  peaks  in  your  spectra;  with  the  instrument  we  are  currently  using,  the  noise  makes  little  difference  as  long  as  you  have  a  quiet  and  steady  background.  Use  the  template  to  calculate  the  GWPs  for  20,  100  and  500  year  time  horizons for each gas and to produce graphs with the IR absorption spectra of the gases overlaid  on  the  emission  spectrum  of  the  earth.  Atmospheric  lifetimes  of  the  gases  used  in  this  experiment  are  150  years  for  CO2,  0.01  years  for  SO2,  15  years  for  CH4,  3200
# 7 years  for  SF6,  14  years  for  CF3CH2F,  120  years  for  N2O,  and  0.41  years  for  CH2Cl2. Make a table that lists the 20, 100 and 500 year time horizon GWPs for your greenhouse gases. Save and close your document. Include a print-out of this file in your lab notebook.

# %% [markdown]
# Notes on using the GWP excel template for this question:
#
# a. The template requires that your IR output is in units of absorbance (A). In Some years, the FTIR has been set to output Transmittance (T), rather than absorbance. If your data are in T, you will need to convert them into A before you read/paste them into the template: A=2−log(%T).
#
# b.Make sure that you are using the pressure and cell pathlength that you measured in lab as input in your template for the spectra that you acquired. For the digital IR spectra for N2O and SF6 that are available on bcourses, assume that the cell pathlength is the same as the one used in this experiment.
#
# c.You may substitute all negative absorbance values with zero. Alternatively, if your spectra do not have sloping baselines, you may make a baseline correction by subtracting a small number from the transmittance value.

# %% [markdown]
# 6.Compare the measured values of the overtone and combination band frequencies for SO2with the values calculated on the basis of the fundamental frequencies, ~ν1, ~ν2 , and ~ν3. Explain the difference between the measured overtone and combination band frequencies and  the  calculated  frequencies.  Discuss  relative  intensities.  Note  that  you  may  need  to  look at your entire spectrum (i.e., 400 cm-1 to 4000 cm-1) and not just over a narrow range to see some of the overtone or combination transitions. If you don't see much difference in  any  of  these  transitions  for  SO2,  here's  a  more  obvious  example:  For  HCl  (a  nice,  simple  diatomic!),  the  fundamental  frequency  is  2885.9  cm-1,  the  1st  overtone  is  5668.1  cm-1, and the third overtone is 8347.0 cm-1. This information on HCl, coupled with your experience  in  previous  labs  this  semester,  may  lead  you  to  the  underlying  reason  that  there  can  be  a  difference  between  the  measured  overtone  and  combination  frequencies  and those calculated from the fundamental frequencies.

# %% [markdown]
# 7.Using  your  own  data  and  the  data  for  SF6  on  bcourses  (which  is  given  in  units  of  absorbance,  by  the  way),  make  a  table  of  the  GWPs  (including  a  column  for  lifetimes),  ordering  the  gases  from  smallest  GWP  to  largest  GWP.  Given  that  the  GWP  of  most  of  the  gases  studied  in  this  experiment  are  much  greater  than  that  of  CO2,  which  by  definition has a GWP of 1, explain why so much attention is being focused on reducing CO2 emissions in order to prevent global warming.

# %% [markdown]
#  8.Compare the GWPs of the greenhouse gases as follows. Explain how the GWP depends on the number, strength, and position of the vibrational bands by including a comparison of the graphs obtained for the gases (all graphs should be brought to your oral exam and affixed  in  your  lab  notebook).  Explain  how  the  GWP  depends  on  the  lifetime  in  the  atmosphere  for  the  gases.  Based  on  these  considerations,  explain  why  some  gases  have  greater  GWPs  than  others.  Why  do  you  think  some  gases  have  longer  atmospheric  lifetimes  than  others?  Can  you  see  any  patterns  in  the  gases  you've  measured/we've  discussed in this lab? Why does the GWP for SF6 increase with increasing time horizon while the GWPs for the other gases decrease with increasing time horizon?

# %% [markdown]
# 9.Note that we are not asking you to compare your GWPs with literature values (although
# 8 some of you may have done so already) but, rather, against each other and on different time horizons from your experimental data analysis.  Can you think of any reasons why the absolute values may not agree with those in the literature? [Hint 1: There is likely to be more than one reasonable reason; Hint 2: read the J. Chem. Ed. Article on bcourses that this experiment is based on.]
